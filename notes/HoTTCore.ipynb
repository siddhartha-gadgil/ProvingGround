// %% [markdown]
// # Core implementation of Homotopy type theory

// %%
load.jar("/home/gadgil/code/ProvingGround/core/.jvm/target/scala-2.11/ProvingGround-Core-assembly-0.8.jar")

// %% [markdown]
// The type A belongs to the first universe

// %%
import provingground._
import HoTT._
val A ="A" :: __
// Out:
// import provingground._
// import HoTT._
// A: provingground.HoTT.Typ[provingground.HoTT.Term] with provingground.HoTT.Subs[provingground.HoTT.Typ[provingground.HoTT.Term]] = A : 𝒰

// %%
val a ="a" :: A
// Out:
// a: Term with Subs[Term] = a : (A : 𝒰 )

// %% [markdown]
// The identity function, as a function of the type A.
// Two lambdas are used, with the method _lmbda_ telling the __compiler__ that the result is a (non-dependent) function.

// %%
val id = lambda(A)(lmbda(a)(a))
// Out:
// id: FuncLike[Typ[Term] with Subs[Typ[Term]], Func[Term with Subs[Term], Term with Subs[Term]]] = (A : 𝒰 ) ↦ ((a : (A : 𝒰 )) ↦ (a : (A : 𝒰 )))

// %% [markdown]
// The lambdas have the same effect at runtime. It is checked if the type of the value depends on the variable.
// The result is either _LambdaFixed_ or _Lambda_ accordingly.

// %%
val indep = lmbda(a)(a)
val dep = lambda(a)(a)
indep == dep
// Out:
// indep: Func[Term with Subs[Term], Term with Subs[Term]] = (a : (A : 𝒰 )) ↦ (a : (A : 𝒰 ))
// dep: FuncLike[Term with Subs[Term], Term with Subs[Term]] = (a : (A : 𝒰 )) ↦ (a : (A : 𝒰 ))
// res4_2: Boolean = true

// %% [markdown]
// A new variable object, which has the same toString, is created in making lambdas. This is to avoid name clashes.

// %%
val l = dep.asInstanceOf[LambdaFixed[Term, Term]]
l.variable
l.variable == a
// Out:
// l: LambdaFixed[Term, Term] = LambdaFixed(a : (A : 𝒰 ), a : (A : 𝒰 ))
// res5_1: Term = a : (A : 𝒰 )
// res5_2: Boolean = false

// %% [markdown]
// We can construct Modus Ponens. Note that _A ->: B_ is the function type

// %%
val B = "B" :: __
val f = "f" :: (A ->: B)
val mp = lambda(A)(lambda(B)(lmbda(a)(lmbda(f)(f(a)))))
// Out:
// B: Typ[Term] with Subs[Typ[Term]] = B : 𝒰
// f: Func[Term, Term] with Subs[Func[Term, Term]] = f : ((A : 𝒰 ) → (B : 𝒰 ))
// mp: FuncLike[Typ[Term] with Subs[Typ[Term]], FuncLike[Typ[Term] with Subs[Typ[Term]], Func[Term with Subs[Term], Func[Func[Term, Term] with Subs[Func[Term, Term]], Term]]]] = (A : 𝒰 ) ↦ ((B : 𝒰 ) ↦ ((a : (A : 𝒰 )) ↦ ((f : ((A : 𝒰 ) → (B : 𝒰 ))) ↦ ((f : ((A : 𝒰 ) → (B : 𝒰 ))) (a : (A : 𝒰 )) : (B : 𝒰 )))))

// %% [markdown]
// We can apply modus ponens with the roles of _A_ and _B_ reversed. This still works because variable clashes are avoided.

// %%
val mpBA = mp(B)(A)
mpBA.typ == B ->: (B ->: A) ->: A
// Out:
// mpBA: Func[Term with Subs[Term], Func[Func[Term, Term] with Subs[Func[Term, Term]], Term]] = (a : (B : 𝒰 )) ↦ ((f : ((B : 𝒰 ) → (A : 𝒰 ))) ↦ ((f : ((B : 𝒰 ) → (A : 𝒰 ))) (a : (B : 𝒰 )) : (A : 𝒰 )))
// res7_1: Boolean = true

// %% [markdown]
// Lambdas do not depend on the name of the variable.

// %%
val aa = "aa" :: A
lmbda(aa)(aa) == lmbda(a)(a)
(lmbda(aa)(aa))(a) == a
// Out:
// aa: Term with Subs[Term] = aa : (A : 𝒰 )
// res8_1: Boolean = true
// res8_2: Boolean = true

// %% [markdown]
// We consider a type family, and construct a Pi-Type. We are using lambdas for the family. Note that the !: method just claims and checks a type, and is useful (e.g. here) for documentation.

// %%
val Bs = "B(_ : A)" :: (A ->: __)
// Out:
// Bs: Func[Term, Typ[Term]] with Subs[Func[Term, Typ[Term]]] = B(_ : A) : ((A : 𝒰 ) → (𝒰 ))

// %%
val fmly = (a !: A) ~>: (Bs(a) ->: A)
// Out:
// fmly: PiTyp[Term, Func[Term, Term]] = PiTyp((a : (A : 𝒰 )) ↦ (((B(_ : A) : ((A : 𝒰 ) → (𝒰 ))) (a : (A : 𝒰 )) : 𝒰 ) → (A : 𝒰 )))

// %% [markdown]
// There is also a convenience method for defining Sigma types using lambdas

// %%
Sgma(a !: A, Bs(a))
// Out:
// res11: SigmaTyp[Term, Term] = SigmaTyp((a : (A : 𝒰 )) ↦ ((B(_ : A) : ((A : 𝒰 ) → (𝒰 ))) (a : (A : 𝒰 )) : 𝒰 ))

// %%
Sgma(a !: A, Bs(a) ->: Bs(a) ->: A)
// Out:
// res12: SigmaTyp[Term, Func[Term, Func[Term, Term]]] = SigmaTyp(
//   (a : (A : 𝒰 )) ↦ (((B(_ : A) : ((A : 𝒰 ) → (𝒰 ))) (a : (A : 𝒰 )) : 𝒰 ) → (((B(_ : A) : ((A : 𝒰 ) → (𝒰 ))) (a : (A : 𝒰 )) : 𝒰 ) → (A : 𝒰 )))
// )
